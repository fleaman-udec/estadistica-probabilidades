# %% [markdown]
# # Módulo: Estadística Descriptiva
# ## T2: Gráficos Estadísticos

# %% [markdown]
# # Objetivos de la clase
#
# - Conocer distintos tipos de gráficos estadísticos y visualizaciones de datos.
# - Discriminar qué tipo de gráfico es útil según el caso de análisis.

# %% [markdown]
# # Gráficos estadísticos
#
# Consisten en técnicas gráficas para **visualizar datos** cuantitativos.
#
# Forman **parte fundamental** del análisis de datos en ciencias e ingeniería, especialmente con el auge actual de la sensorización, el internet de las cosas y la inteligencia artificial
#
# <center>
#     <img src="figures/data-visual-1.jpg" width="500"/>
# </center>

# %% [markdown]
# # Gráficos unidimensionales

# %% [markdown]
# ## Histograma
#
# Es una representación aproximada de la **distribución** de una variable estadística en su rango.
#
# Se divide el rango en **intervalos iguales**, contando cuántos de los datos caen en cada intervalo.
#
#
# <center>
#     <img src="figures/histogram-1.png" width="300"/>
# </center>
#
# El resultado se representa con una **barra de altura proporcional** a la frecuencia (absoluta o relativa) con que la variable está en el intervalo.

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(10)
x1 = np.random.randn(100)*10
n, bins, patches = plt.hist(x1, bins=10, edgecolor='black', density=False)
plt.xlabel('intervalos'), plt.ylabel('variable estadística x'), plt.xticks(bins)
plt.show()

# %% [markdown]
# ## Gráfico de torta
#
# Tiene forma circular y se utiliza para representar **porcentajes o proporciones**.
#
# <center>
#     <img src="figures/pie-1.png" width="400"/>
# </center>
#
# El arco (y ángulo) de cada porción es proporcional a la cantidad que representa.

# %%
estaciones = ['verano', 'otoño', 'invierno', 'primavera']
cantidades = [15, 10, 5, 10]
plt.pie(x=cantidades, labels=estaciones, autopct='%1.1f%%')
plt.title('Preferencias de estaciones del año de 30 estudiantes', fontsize=14)
plt.show()

# %% [markdown]
# ## Gráfico de caja
#
# Se compone de una caja, bigotes y círculos, y busca **resumir la distribución** de una variable estadística.
#
# <center>
#     <img src="figures/boxplot-1.png" width="700"/>
# </center>
#
# La caja sirve para visualizar la tendencia central y asimetría de la muestra por medio de sus cuartiles.
#
# Además, los bigotes y círculos sirven para visualizar la variabilidad fuera del primer y tercer cuartil.

# %%
np.random.seed(46)
x2 = 50 + 10*np.random.randn(100)
box = plt.boxplot([x1, x2], labels=['caso 1', ' caso 2'])
plt.ylabel('variable estadística x')
plt.show()

# %%
fig, ax = plt.subplots()
bplot = ax.boxplot([x1, x2], notch=True, patch_artist=True, labels=['caso 1', 'caso 2'])

colors = ['lightblue', 'lightgreen']
for patch, color in zip(bplot['boxes'], colors):
    patch.set_facecolor(color)        

ax.yaxis.grid(True)
ax.set_ylabel('variable estadística x')
plt.show()

# %% [markdown]
# ## Gráfico de violín
#
# Es parecido al gráfico de caja, pero también muestra una estimación de la densidad de probabilidad de los datos (concepto a ver más adelante).
#
# <center>
#     <img src="figures/violin-1.png" width="600"/>
# </center>

# %%
box = plt.violinplot([x1, x2])
plt.ylabel('variable estadística x')
plt.show()

# %% [markdown]
# # Gráficos bidimensionales

# %% [markdown]
# ## Gráfico de línea
#
# Conecta con una **línea** los valores correspondientes de dos variables estadísticas en un plano Cartesiano.
#
# Se usa principalmente cuando la variable del eje horizontal sigue alguna **progresión ordenada** (usualmente cronológica).
#
# <center>
#     <img src="figures/lineplot-3.png" width="500"/>
# </center>

# %%
x = np.arange(0, 2, 0.01)
y = np.cos(2*np.pi*1.*x + 0.)

plt.plot(x, y, linewidth=2.5)
plt.xlabel('tiempo [s]'), plt.ylabel('velocidad [mm/s]')
plt.grid()
plt.show()

# %%
y1 = 5 + 2*x + np.sin(2*x) + np.random.rand(len(x))*0.1
y2 = 4 + 2*x + np.sin(2*x) + np.random.rand(len(x))*0.1

fig, ax = plt.subplots()
ax.plot(x, y1, label='dia')
ax.plot(x, y2, label='noche')
ax.set_xlabel('tiempo [h]'), ax.set_ylabel('temperatura [°C]')
plt.legend()
plt.show()

# %% [markdown]
# ## Gráfico de línea con margen
# Es una variación del gráfico de línea que **incorpora la variabilidad** de la variable en el eje vertical

# %%
fig, ax = plt.subplots()
ax.fill_between(x, y1, y2, alpha=.5, linewidth=0)
ax.plot(x, (y1 + y2)/2, linewidth=2)
ax.set_xlabel('tiempo [s]'), ax.set_ylabel('temperatura [°C]')
plt.show()

# %% [markdown]
# ## Diagrama de dispersión 2D
#
# Los valores correspondientes de dos variables estadísticas se muestran como **puntos** en un plano.
#
# Se usa para visualizar, comparar y relacionar datos **no necesariamente ordenados**.
#
# <center>
#     <img src="figures/scatter-1.png" width="700"/>
# </center>
#
# Es posible agregar colores o tamaños a los puntos para evaluar una **dimensión adicional**.

# %%
np.random.seed(88)
x3 = 50 + 10*np.random.randn(100)
x4 = 5.5 + 1.5*x3 - 3.3*np.log2(x3) + 15*np.random.rand(100)
x5 = -12.3*np.log2(x3) + 15*np.random.rand(100)

fig, ax = plt.subplots(ncols=2, figsize=(14, 6))
ax[0].scatter(x3, x4), ax[0].set_xlabel('variable x3'), ax[0].set_ylabel('variable x4')
ax[1].scatter(x3, x5, color='red'), ax[1].set_xlabel('variable x3'), ax[1].set_ylabel('variable x5')

ax[0].grid(), ax[1].grid(), plt.tight_layout()
plt.show()

# %% [markdown]
# ## Gráfico de barras
#
# Presenta la **comparación** de variables numéricas de acuerdo a **variables categóricas** usando rectángulos de distinas alturas.
#
# <center>
#     <img src="figures/bar-1.png" width="700"/>
# </center>
#
# Se puede usar para representar más dimensiones agregando rectángulos de distintos colores.

# %%
estaciones = ['verano', 'otoño', 'invierno', 'primavera']
cantidades = [15, 10, 5, 10]
plt.bar(x=np.arange(4), height=cantidades, tick_label=estaciones)
plt.title('Preferencias de estaciones del año de 30 estudiantes')
plt.show()

# %%
estaciones = ['verano', 'otoño', 'invierno', 'primavera']
cantidades_h = [10, 4, 3, 3]
error_h = [1.5, 0.5, 1., 0.5]
cantidades_m = [5, 6, 2, 7]
error_m = [0.5, 1.5, 0.5, 2.5]

idx = np.arange(12)
plt.bar(x=idx[0::3], height=cantidades_h, label='hombres', color='green', yerr=error_h)
plt.bar(x=idx[1::3], height=cantidades_m, label='mujeres', color='orange', yerr=error_m)
plt.xticks(np.linspace(0.5, 9.5, 4), labels=estaciones)

plt.title('Preferencias de estaciones del año de 30 estudiantes'), plt.grid(axis='y'), plt.legend()
plt.show()

# %% [markdown]
# # Gráficos tridimensionales

# %% [markdown]
# ## Mapa de calor
# Muestra una variable estadística en un plano Cartesiano en función de otras dos variables usando un **mapa de colores proporcional a su magnitud**.
#
# <center>
#     <img src="figures/heatmap-1.png" width="700"/>
# </center>

# %%
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)

xv, yv = np.meshgrid(x, y)
zv = np.sin(np.sqrt(xv**2 + yv**2))

#cmaps = viridis, plasma, Reds
fig, ax = plt.subplots()
heatmap = ax.pcolormesh(xv, yv, zv, shading='auto', cmap='plasma')
ax.set_xlabel('variable x'), ax.set_ylabel('variable y')
cbar = plt.colorbar(heatmap)
cbar.set_label('variable z')
plt.show()

# %% [markdown]
# ## Gráfico de superficie
#
# Es la **extensión del gráfico de línea** a tres dimensiones.
#
# <center>
#     <img src="figures/surface-1.png" width="600"/>
# </center>
#
# Muestra mediante una superficie los valores de una variable estadística en función de otras dos variables que siguen una **progresión ordenada**.

# %%
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(xv, yv, zv, color='lightblue')
plt.show()

# %%
#%matplotlib qt
# %matplotlib inline
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(xv, yv, zv, cmap='coolwarm', linewidth=0)
cbar = fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_zticks([])
plt.show()

# %% [markdown]
# ## Diagrama de dispersión 3D
#
# Muestra mediante puntos los valores correspondientes de tres variables estadísticas **no necesariamente ordenadas**.
#
# <center>
#     <img src="figures/scatter3d-1.png" width="700"/>
# </center>
#
# También es posible darles distintos tamaños y colores a los puntos para **agregar otra dimensión**.

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(x3, x4, x5, marker='s', color='blue', label='set 1')
ax.scatter(x1, x2, x3, marker='o', color='red', label='set 2')
plt.legend()
plt.show()

# %% [markdown]
# ## Gráfico de contorno
#
# Es una representación en un plano Cartesiano de una superficie tridimensional.
#
# <center>
#     <img src="figures/contour-1.png" width="800"/>
# </center>
#
# Se consigue realizando **cortes** en la superficie a distintas alturas, los cuales se visualizan en el gráfico mediante un mapa de colores.

# %%
fig, ax = plt.subplots()
cont = ax.contourf(xv, yv, zv, cmap='plasma', levels=5)
ax.set_xlabel('variable x'), ax.set_ylabel('variable y')
cbar = plt.colorbar(cont)
cbar.set_label('variable z')
plt.show()

# %% [markdown]
# # Sumario
# - Los gráficos estadísticos y visualizaciones permiten rápida y eficazmente comprender el comportamiento de una muestra de datos.
# - Hay distintos tipos de gráficos estadísticos y visualizaciones que se deben emplear según sea el caso de análisis.
